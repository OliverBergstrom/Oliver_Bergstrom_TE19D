# %%
# Uppfit 1 - simulering

# %%
# a)

import math

k = 0.5**2 + 0.5**2

svar = math.sqrt(k)

print(f"Avståndet är {svar}")
# Out:
# Avståndet är 0.7071067811865476

# %%
# b)

import math

k = 1**2 + 1**2

svar = math.sqrt(k)

print(f"Avståndet är {svar}")
# Out:
# Avståndet är 1.4142135623730951

# %%
# c)

import math

x = 0.5**2

y = 0 - 0.5

k = x + y**2

svar = math.sqrt(k)

print(f"Avståndet är {svar}")
# Out:
# Avståndet är 0.7071067811865476

# %%
# d)

import random



x = random.uniform(-1,1)
y = random.uniform(-1,1)

svar = 

print(f"x = {x} y = {y}")
# Out:
# x = 0.4671218877181702    y = -0.10965306216441895

# %%
# e)
