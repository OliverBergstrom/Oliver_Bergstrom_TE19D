# %%
n = 0

y = 0

while n < 100:
    n += 1 # räknare, ökar varje gång

    y = y + n # summa   

print(y, end = " ")
# Out:
# 5050

# %%
n = 1

y = 0

while n < 99:
    n += 2

    y = y + n

print(y, end = " ")
# Out:
# 2499
