# %%
'''
    Ett flygplan hållaer konstant hastighet av 800km/h. Efter x h har det hunnit y km

    Värdetabell
    x, y
    0, 0
    1, 800
    2, 1600
    3, 2400
    4, 3200
    5, 4000
'''
# Out:
# '\n    Ett flygplan hållaer konstant hastighet av 800km/h. Efter x h har det hunnit y km\n\n    Värdetabell\n    x, y\n    0, 0\n    1, 800\n    2, 1600\n    3, 2400\n    4, 3200\n    5, 4000\n'

# %%
import matplotlib.pyplot as plt

# lösningsförslag 1 - med listor
x = [0,1,2,3,4,5]
y = [0,800,1600,2400,3200,4000]

plt.plot(x,y, 'o-')
plt.xlabel("Tiden i timmar")
plt.ylabel("Sträcka i km")
plt.title("s-t diagram för ett flygplan med konstant hastighet")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(6)
y = 800*x
print(x)
print(y)

plt.plot(x,y, 'o-')
# Out:
# [0 1 2 3 4 5]
# [   0  800 1600 2400 3200 4000]
