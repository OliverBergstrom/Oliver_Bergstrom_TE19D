# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# fall
df_gender = pd.read_csv("Gender_Data.csv")

män = df_gender[df_gender["Gender"]== "Male"]["Total_Cases"][0]
kvinnor = df_gender[df_gender["Gender"]== "Female"]["Total_Cases"][1]

data = [df_gender["Total_Cases"]]

y = [män, kvinnor]
färg = ["aqua", "magenta"]
plt.pie(y, labels=df_gender["Gender"].tolist(), colors=färg, autopct='%1.1f%%')
plt.legend(title = "Total cases:")
plt.title('total cases')
plt.axis('equal')
plt.show()

df_gender

# dödsfall
df_gender = pd.read_csv("Gender_Data.csv")

män = df_gender[df_gender["Gender"]== "Male"]["Total_Deaths"][0]
kvinnor = df_gender[df_gender["Gender"]== "Female"]["Total_Deaths"][1]

data = [df_gender["Total_Deaths"]]

y = [män, kvinnor]
färg = ["aqua", "magenta"]
plt.pie(y, labels=df_gender["Gender"].tolist(), colors=färg, autopct='%1.1f%%')
plt.legend(title = "Total Deaths:")
plt.title('total deaths')
plt.axis('equal')
plt.show()


df_gender
# Out:
#    Gender  Total_Cases  Total_ICU_Admissions  Total_Deaths
# 0    Male       288507                  3582          6657
# 1  Female       319641                  1411          5771

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

df = pd.read_csv("Age_group.csv")

df
# Out:
#   Age_Group  Total_Cases  Total_ICU_Admissions  Total_Deaths
# 0       0-9         9127                    22             7
# 1     10-19        62180                    35             3
# 2     20-29       107936                   142            15
# 3     30-39       107508                   194            33
# 4     40-49       109903                   483            81
# 5     50-59       101188                  1084           261
# 6     60-69        53511                  1438           721
# 7     70-79        26476                  1259          2605
# 8     80-89        20538                   329          5239
# 9       90+         9980                     7          3463

# %%
print(män["Total_C)
# Out:
# 0    288507
# Name: Total_Cases, dtype: int64

# %%
kvinnor
# Out:
#    Gender  Total_Cases  Total_ICU_Admissions  Total_Deaths
# 1  Female       319641                  1411          5771
