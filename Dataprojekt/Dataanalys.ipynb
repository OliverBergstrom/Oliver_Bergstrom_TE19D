# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# fall
df_gender = pd.read_csv("Gender_Data.csv") # Importerar filen vi hämtar datan ifrån

män = df_gender[df_gender["Gender"]== "Male"]["Total_Cases"][0] # Gör så att vi får fram antalet fall som var män
kvinnor = df_gender[df_gender["Gender"]== "Female"]["Total_Cases"][1] # Gör så vi får fram antal fall som var kvinnor

data = [df_gender["Total_Cases"]] # Använder datan fån total cases för att göra ett cirkel diagram.

y = [män, kvinnor] # Lägger in antallet fall av män och kvinnor.

färg = ["aqua", "hotpink"] # Ändrar färg så att den delen som representerar män är blå och den delen som representerar kvinnor är rosa.

plt.pie(y, labels=df_gender["Gender"].tolist(), colors=färg, autopct='%1.1f%%') # Labels namnger varsin del till Male eller Female. Colors tar från listan färger och använder de. Autopct gör att den visar antalet procent.
plt.legend(title = "Total cases:") # Lägger till en liten ruta som har lite information om diagrammet
plt.title('total cases') # Diagrammets titel
plt.axis('equal') # Gör så att bilden av diagramet blir större på bredden så info rutan får plats
plt.show() # Visar diagrammet

df_gender

# dödsfall
df_gender = pd.read_csv("Gender_Data.csv") # Importerar filen vi hämtar datan ifrån

män = df_gender[df_gender["Gender"]== "Male"]["Total_Deaths"][0] # Gör så att vi får fram antalet dödsfall som var män
kvinnor = df_gender[df_gender["Gender"]== "Female"]["Total_Deaths"][1] # Gör så vi får fram antal dödsfall som var kvinnor

data = [df_gender["Total_Deaths"]] # Använder datan fån total cases för att göra ett cirkel diagram

y = [män, kvinnor] # Lägger in antallet dödsfall av män och kvinnor.
färg = ["aqua", "hotpink"] # Ändrar färg så att den delen som representerar män är blå och den delen som representerar kvinnor är rosa.
plt.pie(y, labels=df_gender["Gender"].tolist(), colors=färg, autopct='%1.1f%%') # Labels namnger varsin del till Male eller Female. Colors tar från listan färger och använder de. Autopct gör att den visar antalet procent.
plt.legend(title = "Total Deaths:") # Lägger till en liten ruta som har lite information om diagrammet
plt.title('total deaths') # Diagrammets titel
plt.axis('equal') # Gör så att bilden av diagramet blir större på bredden så info rutan får plats
plt.show() # Visar diagrammet


df_gender
# Out:
#    Gender  Total_Cases  Total_ICU_Admissions  Total_Deaths
# 0    Male       288507                  3582          6657
# 1  Female       319641                  1411          5771

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# Fall
df_age = pd.read_csv("Age_group.csv") # Importerar filen vi hämtar datan ifrån

x = np.array(df_age["Age_Group"]) # Gör så att x axeln visar åldersgrupper
y = np.array(df_age["Total_Cases"]) # Gör så y axeln visar antal fall vid dessa åldersgrupper

plt.xlabel("Fall") # Namnet på x axeln
plt.ylabel("Ålder") # Namnet på y axeln

plt.barh(x, y, color = "lime") # Skapar diagrammet där staplarna är lime
plt.show() # Visar diagrammet

# Dödsfall

df_age = pd.read_csv("Age_group.csv") # Importerar filen vi hämtar datan ifrån

x = np.array(df_age["Age_Group"]) # Gör så att x axeln visar åldersgrupper
y = np.array(df_age["Total_Deaths"]) # Gör så y axeln visar antal dödsfall vid dessa åldersgrupper

plt.xlabel("Dödsfall") # Namnet på x axeln
plt.ylabel("Ålder") # Namnet på y axeln

plt.barh(x, y,color = "yellow") # Skapar diagrammet där staplarna är gula
plt.show() # Visar diagrammet

df_age
# Out:
#   Age_Group  Total_Cases  Total_ICU_Admissions  Total_Deaths
# 0       0-9         9127                    22             7
# 1     10-19        62180                    35             3
# 2     20-29       107936                   142            15
# 3     30-39       107508                   194            33
# 4     40-49       109903                   483            81
# 5     50-59       101188                  1084           261
# 6     60-69        53511                  1438           721
# 7     70-79        26476                  1259          2605
# 8     80-89        20538                   329          5239
# 9       90+         9980                     7          3463
